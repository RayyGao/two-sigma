# %%
import pandas as pd
import numpy as np

# %%
vote=pd.read_csv('voteResult.csv',index_col=0)

# %%
kera=pd.read_csv('keras__test_full.csv',index_col=0)

# %%
cp=(vote+kera)/2

# %%
cp.to_csv('composite.csv')

# %%
kera.columns
# Out:
# Index([u'high', u'medium', u'low'], dtype='object')

# %%
vote.columns
# Out:
# Index([u'high', u'medium', u'low'], dtype='object')

# %%
cp
# Out:
#                 high    medium       low
# listing_id
# 7142618     0.029356  0.258008  0.712636
# 6922984     0.053265  0.248467  0.698268
# 6860805     0.029356  0.258008  0.712636
# 7113840     0.166328  0.418744  0.414928
# 6843735     0.001729  0.062176  0.936095
# 7098659     0.032275  0.044365  0.923360
# 7209423     0.026096  0.074129  0.899774
# 7099874     0.014214  0.159228  0.826559
# 7098442     0.024528  0.106942  0.868529
# 7225900     0.002831  0.020982  0.976187
# 7170692     0.002566  0.025177  0.972257
# 7226712     0.002261  0.012178  0.985561
# 7210643     0.008056  0.031179  0.960765
# 7232655     0.013311  0.050749  0.935940
# 7098880     0.001386  0.011343  0.987272
# 6849183     0.016521  0.225320  0.758159
# 7099119     0.005726  0.025340  0.968934
# 7200523     0.005107  0.066143  0.928750
# 7171562     0.002001  0.024332  0.973667
# 7226762     0.000326  0.014170  0.985503
# 7226918     0.002415  0.022159  0.975426
# ...
